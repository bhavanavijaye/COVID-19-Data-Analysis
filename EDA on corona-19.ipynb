# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rinichristy/covid19-coronavirus-pandemic")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'covid19-coronavirus-pandemic' dataset.
# Path to dataset files: /kaggle/input/covid19-coronavirus-pandemic

# %%
from google.colab import files
uploaded = files.upload()

df = pd.read_csv(list(uploaded.keys())[0])
df.head()
# Out:
#      <input type="file" id="files-64ab60e9-dca5-46f5-bbef-cac19eb411af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64ab60e9-dca5-46f5-bbef-cac19eb411af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.describe()
# Out:
#          Population   Total Cases  Total Deaths  Tot Cases//1M pop  \
# count  2.250000e+02  2.250000e+02  2.250000e+02         225.000000
# mean   3.507321e+07  2.184781e+06  2.744813e+04      136900.373333
# std    1.392418e+08  7.275938e+06  9.689177e+04      145060.340289
# min    8.050000e+02  1.000000e+00  0.000000e+00           9.000000
# 25%    5.665570e+05  2.407100e+04  1.890000e+02       11384.000000
# 50%    5.827911e+06  1.639360e+05  1.965000e+03       88987.000000
# 75%    2.190585e+07  1.092547e+06  1.366000e+04      223335.000000
# max    1.439324e+09  8.183905e+07  1.008222e+06      696044.000000
#
#        Tot Deaths/1M pop  Death percentage
# count         225.000000        225.000000
# mean         1096.715556          1.444125
# std          1195.715543          1.741728
# min             0.000000          0.000000
# 25%           123.000000          0.511291
# 50%           708.000000          1.036905
# 75%          1795.000000          1.977017
# ...

# %%
df= pd.read_csv('archive (12).zip')

# %%
df.head()
# Out:
#        Country  Other names ISO 3166-1 alpha-3 CODE  Population Continent  \
# 0  Afghanistan  Afghanistan                     AFG    40462186      Asia
# 1      Albania      Albania                     ALB     2872296    Europe
# 2      Algeria      Algeria                     DZA    45236699    Africa
# 3      Andorra      Andorra                     AND       77481    Europe
# 4       Angola       Angola                     AGO    34654212    Africa
#
#    Total Cases  Total Deaths  Tot Cases//1M pop  Tot Deaths/1M pop  \
# 0       177827          7671               4395                190
# 1       273870          3492              95349               1216
# 2       265691          6874               5873                152
# 3        40024           153             516565               1975
# 4        99194          1900               2862                 55
#
#    Death percentage
# 0          4.313743
# 1          1.275058
# 2          2.587216
# 3          0.382271
# ...

# %%
df.head()
df.describe()
# Out:
#          Population   Total Cases  Total Deaths  Tot Cases//1M pop  \
# count  2.250000e+02  2.250000e+02  2.250000e+02         225.000000
# mean   3.507321e+07  2.184781e+06  2.744813e+04      136900.373333
# std    1.392418e+08  7.275938e+06  9.689177e+04      145060.340289
# min    8.050000e+02  1.000000e+00  0.000000e+00           9.000000
# 25%    5.665570e+05  2.407100e+04  1.890000e+02       11384.000000
# 50%    5.827911e+06  1.639360e+05  1.965000e+03       88987.000000
# 75%    2.190585e+07  1.092547e+06  1.366000e+04      223335.000000
# max    1.439324e+09  8.183905e+07  1.008222e+06      696044.000000
#
#        Tot Deaths/1M pop  Death percentage
# count         225.000000        225.000000
# mean         1096.715556          1.444125
# std          1195.715543          1.741728
# min             0.000000          0.000000
# 25%           123.000000          0.511291
# 50%           708.000000          1.036905
# 75%          1795.000000          1.977017
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  225 non-null    object
#  1   Other names              224 non-null    object
#  2   ISO 3166-1 alpha-3 CODE  225 non-null    object
#  3   Population               225 non-null    int64
#  4   Continent                225 non-null    object
#  5   Total Cases              225 non-null    int64
#  6   Total Deaths             225 non-null    int64
#  7   Tot Cases//1M pop        225 non-null    int64
#  8   Tot Deaths/1M pop        225 non-null    int64
#  9   Death percentage         225 non-null    float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 17.7+ KB

# %%
df.isnull().sum()
# Out:
# Country                    0
# Other names                1
# ISO 3166-1 alpha-3 CODE    0
# Population                 0
# Continent                  0
# Total Cases                0
# Total Deaths               0
# Tot Cases//1M pop          0
# Tot Deaths/1M pop          0
# Death percentage           0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 220    False
# 221    False
# 222    False
# 223    False
# 224    False
# Length: 225, dtype: bool

# %%
  import matplotlib.pyplot as plt

# %%
df.boxplot(column=["Tot\xa0Deaths/1M pop"])
plt.show()

# %%
numeric_df = df.select_dtypes(include=['int64','float64'])
numeric_df.boxplot()
plt.show()

# %%
print(f"Duplicate rows: {df.duplicated().sum()}")
# Out:
# Duplicate rows: 0

# %%
print(df.columns.tolist())
# Out:
# ['Country', 'Other names', 'ISO 3166-1 alpha-3 CODE', 'Population', 'Continent', 'Total Cases', 'Total Deaths', 'Tot\xa0Cases//1M pop', 'Tot\xa0Deaths/1M pop', 'Death percentage']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 6))
sns.histplot(df['Tot\xa0Deaths/1M pop'], bins=20, kde=True)
# Out:
# <Axes: xlabel='Tot\xa0Deaths/1M pop', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 6))
sns.histplot(df['Tot\xa0Deaths/1M pop'], bins=20, kde=True)
plt.title('Distribution')
plt.xlabel('Deaths')
plt.ylabel('cases')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Continent', data=df,palette= 'viridis' )
plt.title('Continent')
plt.show()
# Out:
# /tmp/ipykernel_24269/883084670.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Continent', data=df,palette= 'viridis' )

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Continent', data=df)
plt.title('Box Plot of Income')
plt.show()

# %%
import pandas as pd

numeric_col = df.select_dtypes(include=['number']).columns

outlier_report = {}

for col in numeric_col:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

    outlier_report[col] = len(outliers)

    print(f"Column: {col}")
    print(f"Number of Outliers: {len(outliers)}")
    print(f"Lower Bound: {lower_bound}")
    print(f"Upper Bound: {upper_bound}")
    print("\n Outlier Detection Completed\n")
# Out:
# Column: Population
# Number of Outliers: 27
# Lower Bound: -31442379.5
# Upper Bound: 53914784.5
#
#  Outlier Detection Completed
#
# Column: Total Cases
# Number of Outliers: 38
# Lower Bound: -1578643.0
# Upper Bound: 2695261.0
#
#  Outlier Detection Completed
#
# Column: Total Deaths
# Number of Outliers: 29
# Lower Bound: -20017.5
# Upper Bound: 33866.5
#
#  Outlier Detection Completed
#
# Column: Tot Cases//1M pop
# Number of Outliers: 1
# Lower Bound: -306542.5
# Upper Bound: 541261.5
#
#  Outlier Detection Completed
#
# Column: Tot Deaths/1M pop
# Number of Outliers: 6
# Lower Bound: -2385.0
# Upper Bound: 4303.0
#
#  Outlier Detection Completed
#
# Column: Death percentage
# Number of Outliers: 10
# Lower Bound: -1.6872982375000003
# Upper Bound: 4.1756064225000005
#
#  Outlier Detection Completed

# %%
def cap_outliers(df, column):
  Q1=df[column].quantile(0.25)
  Q3=df[column].quantile(0.75)
  IQR=Q3-Q1
  IQR = Q3-Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  df[column]= df[column].clip(lower_bound, upper_bound)
  return df
  for col in numeric_col:
    if col not in ['Continent','Population']:
      cap_outliers(df, col)

# %%
print(df.columns.tolist())
# Out:
# ['Country', 'Other names', 'ISO 3166-1 alpha-3 CODE', 'Population', 'Continent', 'Total Cases', 'Total Deaths', 'Tot\xa0Cases//1M pop', 'Tot\xa0Deaths/1M pop', 'Death percentage']

# %%
cols_to_plot = [col for cols in numeric_col if cols not in ['Total Cases', 'Total Deaths']]
plt.figure(figsize=(12, 6))
for i, col in enumerate(cols_to_plot,1):
  plt.subplot(2,2,i)
  sns.boxplot(df[col],color= "skyblue" )
  plt.title(f"Box Plot of {col}")
plt.tight_layout()
plt.show()

# %%
numeric_df= df.select_dtypes(include=["number"])

numeric_df = numeric_df.drop(columns=['index', 'postal_code'],errors = 'ignore')

plt.figure(figsize=(12, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt ='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
columns_to_encode = ['Population', 'Continent', 'Total Cases', 'Total Deaths']
df_encoded = pd.get_dummies(df, columns=columns_to_encode,drop_first=True)
#
print(df_encoded.head())
# Out:
#        Country  Other names ISO 3166-1 alpha-3 CODE  Tot Cases//1M pop  \
# 0  Afghanistan  Afghanistan                     AFG               4395
# 1      Albania      Albania                     ALB              95349
# 2      Algeria      Algeria                     DZA               5873
# 3      Andorra      Andorra                     AND             516565
# 4       Angola       Angola                     AGO               2862
#
#    Tot Deaths/1M pop  Death percentage  Population_1645  Population_3657  \
# 0                190          4.313743            False            False
# 1               1216          1.275058            False            False
# 2                152          2.587216            False            False
# 3               1975          0.382271            False            False
# 4                 55          1.915438            False            False
#
#    Population_4997  Population_5744  ...  Total Deaths_142506  \
# ...

# %%
final_df = df_encoded
print(final_df.head())
# Out:
#        Country  Other names ISO 3166-1 alpha-3 CODE  Tot Cases//1M pop  \
# 0  Afghanistan  Afghanistan                     AFG               4395
# 1      Albania      Albania                     ALB              95349
# 2      Algeria      Algeria                     DZA               5873
# 3      Andorra      Andorra                     AND             516565
# 4       Angola       Angola                     AGO               2862
#
#    Tot Deaths/1M pop  Death percentage  Population_1645  Population_3657  \
# 0                190          4.313743            False            False
# 1               1216          1.275058            False            False
# 2                152          2.587216            False            False
# 3               1975          0.382271            False            False
# 4                 55          1.915438            False            False
#
#    Population_4997  Population_5744  ...  Total Deaths_142506  \
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = numeric_df.dropna()
y = X.iloc[:, 0]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)

print("Model trained successfully")
# Out:
# Model trained successfully

# %% [markdown]
# INSIGHTS:
# - Total COVID-19 cases are significantly higher in North America and Europe compared to other continents, suggesting a wider spread of the virus and possibly better detection and reporting systems in these regions.
# - Higher death counts are observed in North America and Latin America & the Caribbean, indicating a severe impact of COVID-19 in these regions, which may be influenced by factors such as population size, healthcare capacity, and spread of infection.
# - A strong positive correlation exists between total cases and total deaths, showing that countries with more cases tend to have higher fatalities.
# - The distribution of deaths per million is right-skewed, meaning most countries have lower death rates while a few countries show extremely high values.
# - Significant outliers are present in death-related and case-related columns, representing heavily affected countries or possible reporting variations.
# - Population alone does not determine the severity of deaths per million, suggesting that healthcare systems and response strategies also play a crucial role.
# - Variation across continents indicates uneven spread and impact of COVID-19 globally.
# - Data visualization helped identify patterns, trends, and anomalies effectively.
# - Outlier detection and handling improved the reliability of the dataset for further analysis.
